# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
data = pd.read_csv('model6.csv')

# %%
x = data.t

# %%
plt.plot(x, data['1uM'])
plt.plot(x, data['1.4uM'])
plt.plot(x, data['2uM'])
plt.plot(x, data['4uM'])

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [1], line 1
# ----> 1 from Hypergraph.species_hypergraph import Reaction
#
# ModuleNotFoundError: No module named 'Hypergraph'
